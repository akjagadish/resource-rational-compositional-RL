# %% [markdown]
# ## Figure 0

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# from plos import generate_reward_structures
# generate_reward_structures(sub_task=1, n_runs=1, FIGSIZE=(5,5), FONTSIZE=25)

# %% [markdown]
# ## Figure 1

# %% [markdown]
# #### model simulation regrets on the task

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import simulated_models_meanregrets
#/eris/u/ajagadish/compositional-reinforcement-learniang
simulated_models_meanregrets(trials=np.arange(10, 15), FIGSIZE=(5,5), FONTSIZE=20, path="/notebooks/modelfits/simulated_data_preds/optimal")

# %% [markdown]
# #### RL3 Simulations: dl vs regrets or p(opt)

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import simulated_dls_meanregrets
simulated_dls_meanregrets(trials=np.arange(10, 15), FIGSIZE=(5,5), FONTSIZE=20)
# Out:
# No handles with labels found to put in legend.

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import simulated_dls_meanprobs
simulated_dls_meanprobs(trials=np.arange(10, 11), FIGSIZE=(5,5), FONTSIZE=20)
# Out:
# No handles with labels found to put in legend.

# %%
import sys
sys.path.append('../plots/' )
import numpy as np
from plos import rl3_regrettrace
rl3_regrettrace()
# Out:
# ../plots/plos.py:205: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matricesor `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at  ../aten/src/ATen/native/TensorShape.cpp:2318.)
#   ax.plot(np.arange(1, 6), rl3_regrets.mean(1)[int(jj), plot_trials].T,  color=cmap.to_rgba(ii + 1), lw=2, linestyle='solid')

# %% [markdown]
# ## Figure 2

# %% [markdown]
# ### regrets

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import human_meanregrets_trials
human_meanregrets_trials(FIGSIZE=(5,5), FONTSIZE=20)
# Out:
# compositional [2.1634766  2.32735263 1.91237429 1.65121532 1.45205841] [0.1161112  0.12333432 0.10647715 0.10255812 0.11134453]
# noncompositional [4.05530269 3.52665409 2.97766093 2.4329972  2.40432517] [0.05885058 0.07870361 0.09973395 0.10316825 0.12568943]
# compositional [1.9372096  1.8187608  1.48644748 1.27322783 1.12864806] [0.08076387 0.08509017 0.08362603 0.0859638  0.08490258]
# noncompositional [3.09616089 2.62849889 2.30723378 2.00305079 1.75197574] [0.06013775 0.05754178 0.06467599 0.08208457 0.09023578]

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import human_meanregrets_primitivies
human_meanregrets_primitivies(FIGSIZE=(5,5), FONTSIZE=20)

# %% [markdown]
# ### probs

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import human_meanprobs
human_meanprobs(first=True, FIGSIZE=(5,5), FONTSIZE=20)

# %% [markdown]
# ### choices

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

#first trial of compositonal task
from plos import histogram_peoplechoices
histogram_peoplechoices(trials=np.arange(1), FONTSIZE=20, FIGSIZE=(5,5), include_optimal=True) #FIGSIZE=(3,3), FONTSIZE=10)

# %% [markdown]
# ### regrets to choices

# %%
import sys
sys.path.append('../plots/' )
import numpy as np

from plos import analysis_of_regrets
analysis_of_regrets(FONTSIZE=20)
# Out:
# (20000,)
# (20000,)
# (20000,)
# (20000,)
# (20000,)
# (20000,)
# (20000,)
# (20000,)

# %% [markdown]
# ## Figure 3

# %% [markdown]
# #### Model Comparison

# %% [raw]
# !pip install groupBMC==1.0

# %%
import sys
sys.path.append('../plots/' )
from plos import posterior_model_frequency_mlls_perrule
posterior_model_frequency_mlls_perrule(fit_trials='first', FIGSIZE=(10,5), FONTSIZE=20)
# Out:
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [0.70426434 0.00180001 0.00180763 0.00180459 0.28851884 0.00180459] [2.21570296e-03 1.91145225e-05 1.91953733e-05 1.91631156e-05
#  2.18378425e-03 1.91631054e-05]
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [0.74092854 0.00153147 0.00153182 0.00152912 0.25294993 0.00152912] [1.72931027e-03 1.37758578e-05 1.37790689e-05 1.37547806e-05
#  1.70239877e-03 1.37548097e-05]

# %%
import sys
sys.path.append('../plots/' )
from plos import exeedance_probability_mlls_perrule
exeedance_probability_mlls_perrule(fit_trials='first', FIGSIZE=(10,5), FONTSIZE=20)
# Out:
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [9.99999996e-01 1.54102001e-22 1.55159962e-22 1.54737334e-22
#  4.32889456e-09 1.54737200e-22]
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [9.99999999e-01 3.08848628e-29 3.08965478e-29 3.08082289e-29
#  5.42295520e-10 3.08083345e-29]

# %% [markdown]
# #### Fitted Model Recovery

# %%
rule = 'changepoint'
actions, _, regrets, best = np.load(f'/notebooks/modelfits/simulated_data_preds/mean_tracker_compositional/stats_mean_tracker_compositional_simulated_compositional_{rule}_composed.npy')

# %%
import sys
sys.path.append('../plots/' )
import numpy as np
from plos import fitted_model_simulated_meanprobs
fitted_model_simulated_meanprobs(fit_subtasks='first', FIGSIZE=(6,5), FONTSIZE=20)
# Out:
# [0.38260869565217404, tensor(0.3663), 0.45877717391304346] [0.020486099744265136, tensor(0.0154), 0.015657433001086376]
# [0.3371559633027522, tensor(0.2922), 0.2882110091743119] [0.01573606680164971, tensor(0.0132), 0.007301802222493106]

# %% [markdown]
# #### model comparison all trials

# %%
import sys
sys.path.append('../plots/' )
from plos import posterior_model_frequency
posterior_model_frequency(FIGSIZE=(10,5), FONTSIZE=20)
# Out:
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [0.32991829 0.00179275 0.07141252 0.00183268 0.31648547 0.2785583 ] [2.35183203e-03 1.90376167e-05 7.05455032e-04 1.94608154e-05
#  2.30130230e-03 2.13791036e-03]
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [0.18186664 0.00151569 0.0015228  0.01322103 0.17773779 0.62413604] [1.34046097e-03 1.36341395e-05 1.36980033e-05 1.17533679e-04
#  1.31664027e-03 2.11342561e-03]

# %%
import sys
sys.path.append('../plots/' )
from plos import exceedance_probability
exceedance_probability(FIGSIZE=(10,5), FONTSIZE=20)
# Out:
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [4.83349179e-01 1.18806100e-14 2.99636394e-07 1.23123797e-14
#  3.68028779e-01 1.48621742e-01]
# ['RR-RL$^2$', 'RL$^2$', 'Compositional\nGPR', 'GPR', 'Compositional\nBMT', 'BMT'] [5.11240167e-11 1.39664673e-23 1.40724888e-23 6.58324334e-21
#  4.23833586e-11 1.00000000e+00]

# %%
import sys
sys.path.append('../plots/' )
from plos import trial_wise_MLLs
trial_wise_MLLs(FIGSIZE=(5,5), FONTSIZE=20)

# %% [markdown]
# #### model comparison last trial

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# from plos import posterior_model_frequency_mlls_perrule
# posterior_model_frequency_mlls_perrule(fit_trials='last', FIGSIZE=(10,5), FONTSIZE=20)
#
# import sys
# sys.path.append('../plots/' )
# from plos import exeedance_probability_mlls_perrule
# exeedance_probability_mlls_perrule(fit_trials='last', FIGSIZE=(10,5), FONTSIZE=20)

# %% [raw]
# %debug

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
# from make_plots import fitted_RL3_people_regrets
# fitted_RL3_people_regrets(fit_subtasks='composed', FIGSIZE=(5,5), FONTSIZE=20)
#
# import sys
# sys.path.append('../plots/' )
# import numpy as np
# #first trial of compositonal task
# from make_plots import histogram_model_simualtion_people
# histogram_model_simualtion_people(trials=np.arange(1), FONTSIZE=25, FIGSIZE=(7,7)) #FIGSIZE=(3,3), FONTSIZE=10)
#
# import sys
# sys.path.append('../plots/' )
# import numpy as np
# from make_plots import simulated_RL3_people_regret
# simulated_RL3_people_regret(fit_subtasks='composed', FIGSIZE=(5,5), FONTSIZE=20)
#
# import sys
# sys.path.append('../plots/' )
# import numpy as np
# from make_plots import fitted_model_simulation_regret
# fitted_model_simulation_regret(fit_subtasks='all', FIGSIZE=(5,5), FONTSIZE=20)

# %% [markdown]
# #### RL3: dls vs regrets/probs

# %%
import sys
sys.path.append('../plots/' )
from plos import fitted_dls_grouped_human_choices
fitted_dls_grouped_human_choices(trials=range(10,11), FIGSIZE=(5,5), FONTSIZE=20)
# Out:
# No handles with labels found to put in legend.
#                             OLS Regression Results
# ...
# Dep. Variable:                  probs   R-squared:                       0.129
# Model:                            OLS   Adj. R-squared:                  0.119
# Method:                 Least Squares   F-statistic:                     13.32
# Date:                Fri, 12 May 2023   Prob (F-statistic):           0.000440
# Time:                        18:58:31   Log-Likelihood:                 25.501
# No. Observations:                  92   AIC:                            -47.00
# Df Residuals:                      90   BIC:                            -41.96
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.1355      0.070      1.924      0.058      -0.004       0.275
# ...

# %% [raw]
# import numpy as np
# np.sqrt(0.129), np.sqrt(0.238)
#
# import numpy as np
# np.sqrt(0.130), np.sqrt(0.201)

# %% [markdown]
# #### grouped RL3 show composning and non-composing behavior

# %%
import sys
import numpy as np
sys.path.append('../plots/' )
from plos import fitted_dls_grouped_histogram_peoplechoices
fitted_dls_grouped_histogram_peoplechoices(trials=np.array([0]), FONTSIZE=20, FIGSIZE=(5,5), include_optimal=True) #FIGSIZE=(3,3), FONTSIZE=10)
# Out:
# tensor(17) tensor(39)
# tensor(25) tensor(58)

# %% [markdown]
# #### analysis of regrets for RR-RL2

# %%
import sys
sys.path.append('../plots/' )

from plos import fitted_models_analysis_of_regrets
fitted_models_analysis_of_regrets(model_name='rl3', FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
#
# from plos import fitted_models_analysis_of_regrets
# fitted_models_analysis_of_regrets(model_name='mean_tracker_compositional', FONTSIZE=20)

# %%
import sys
sys.path.append('../plots/' )

from plos import corner_arms_over_dls
corner_arms_over_dls(FONTSIZE=20)

# %% [raw]
# %debug

# %% [markdown]
# ## archive

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
# from make_plots import fitted_RL3_people_probs
# fitted_RL3_people_probs(fit_subtasks='composed', FIGSIZE=(5,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# from make_plots import model_comparison_mlls_perrule
# model_comparison_mlls_perrule(rule='add', horizontal=True, FIGSIZE=(10,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# from make_plots import model_comparison_mlls_perrule
# model_comparison_mlls_perrule(rule='changepoint', FIGSIZE=(10,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# from make_plots import model_comparison_mlls_per_trial
# model_comparison_mlls_per_trial(models=['mean_tracker', 'mean_tracker_compositional','rbf_nocontext_nomemory', 'simple_grammar_constrained', 'rl2', 'rl3'], fit_subtasks='composed', fit_trials='first', FIGSIZE=(10,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# from make_plots import human_regrets
# human_regrets(first=True, FIGSIZE=(5,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# from make_plots import human_regrets
# human_regrets(first=False, FIGSIZE=(5,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# from make_plots import human_probs_optimal
# human_probs_optimal(first=True, FIGSIZE=(5,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# from make_plots import human_probs_optimal
# human_probs_optimal(first=False, FIGSIZE=(5,5), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# #all trials of compositonal task
# from make_plots import histogram_peoplechoices
# histogram_peoplechoices(trials=np.arange(5), FONTSIZE=25, FIGSIZE=(7,7)) #FIGSIZE=(3,3), FONTSIZE=10)

# %% [raw]
# ## first trial
#
# import sys
# sys.path.append('../plots/' )
# from make_plots import rl3_peopleregrets_entropymodels
# rl3_peopleregrets_entropymodels(trials=range(10,11), FIGSIZE=(7,7), FONTSIZE=20)
#
# # import sys
# # sys.path.append('../plots/' )
# # from make_plots import rl3_peopleprobs_entropymodels
# # rl3_peopleprobs_entropymodels(trials=range(10,11), FIGSIZE=(7,7), FONTSIZE=20)

# %% [raw]
# ### last subtask
#
# import sys
# sys.path.append('../plots/' )
# from make_plots import rl3_peopleregrets_entropymodels
# rl3_peopleregrets_entropymodels(trials=range(10,15), FIGSIZE=(7,7), FONTSIZE=20)
#
# import sys
# sys.path.append('../plots/' )
# from make_plots import rl3_peopleprobs_entropymodels
# rl3_peopleprobs_entropymodels(trials=range(10,15), FIGSIZE=(7,7), FONTSIZE=20)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# # all trials of composed task
# from make_plots import rl3_peoplechoices_percomposition_entropy_models
# _ = rl3_peoplechoices_percomposition_entropy_models(trials=np.arange(0,5), FONTSIZE=20, FIGSIZE=(5,5)) #FIGSIZE=(3,3), FONTSIZE=10)

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# import numpy as np
#
# # all trials of composed task
# from make_plots import models_peoplechoices_kld
# models_peoplechoices_kld(trials=np.arange(5), FONTSIZE=20, FIGSIZE=(5,5))
#
#
# # # first trials of composed task
# # from make_plots import rl3_entropy_peoplechoices_kld
# # models_peoplechoices_kld(trials=np.arange(5), FONTSIZE=20, FIGSIZE=(5,5))

# %% [raw]
# import sys
# sys.path.append('../plots/' )
# from make_plots import KL_divergences_people_models_plos
# KL_divergences_people_models_plos(FONTSIZE=20)
